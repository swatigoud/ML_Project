# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
# %matplotlib inline

# %%
df = pd.DataFrame

# %%
df= pd.read_csv("C:\\Users\\Swati Goud\\Downloads\\melb_data1.csv")
print(df.head())
# Out:
#    Unnamed: 0      Suburb           Address  Rooms Type      Price Method  \
# 0           1  Abbotsford      85 Turner St      2    h  1480000.0      S
# 1           2  Abbotsford   25 Bloomburg St      2    h  1035000.0      S
# 2           4  Abbotsford      5 Charles St      3    h  1465000.0     SP
# 3           5  Abbotsford  40 Federation La      3    h   850000.0     PI
# 4           6  Abbotsford       55a Park St      4    h  1600000.0     VB
#
#   SellerG       Date  Distance  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  Biggin  3/12/2016       2.5  ...       1.0  1.0     202.0           NaN
# 1  Biggin  4/02/2016       2.5  ...       1.0  0.0     156.0          79.0
# 2  Biggin  4/03/2017       2.5  ...       2.0  0.0     134.0         150.0
# 3  Biggin  4/03/2017       2.5  ...       2.0  1.0      94.0           NaN
# 4  Nelson  4/06/2016       2.5  ...       1.0  2.0     120.0         142.0
#
# ...

# %%
df.shape
# Out:
# (18396, 22)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Suburb', 'Address', 'Rooms', 'Type', 'Price', 'Method',
#        'SellerG', 'Date', 'Distance', 'Postcode', 'Bedroom2', 'Bathroom',
#        'Car', 'Landsize', 'BuildingArea', 'YearBuilt', 'CouncilArea',
#        'Lattitude', 'Longtitude', 'Regionname', 'Propertycount'],
#       dtype='str')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 18396 entries, 0 to 18395
# Data columns (total 22 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     18396 non-null  int64
#  1   Suburb         18396 non-null  str
#  2   Address        18396 non-null  str
#  3   Rooms          18396 non-null  int64
#  4   Type           18396 non-null  str
#  5   Price          18396 non-null  float64
#  6   Method         18396 non-null  str
#  7   SellerG        18396 non-null  str
#  8   Date           18396 non-null  str
#  9   Distance       18395 non-null  float64
#  10  Postcode       18395 non-null  float64
#  11  Bedroom2       14927 non-null  float64
#  12  Bathroom       14925 non-null  float64
#  13  Car            14820 non-null  float64
#  14  Landsize       13603 non-null  float64
#  15  BuildingArea   7762 non-null   float64
#  16  YearBuilt      8958 non-null   float64
#  17  CouncilArea    12233 non-null  str
# ...

# %%
df.isnull
# Out:
# <bound method DataFrame.isnull of        Unnamed: 0        Suburb           Address  Rooms Type      Price  \
# 0               1    Abbotsford      85 Turner St      2    h  1480000.0
# 1               2    Abbotsford   25 Bloomburg St      2    h  1035000.0
# 2               4    Abbotsford      5 Charles St      3    h  1465000.0
# 3               5    Abbotsford  40 Federation La      3    h   850000.0
# 4               6    Abbotsford       55a Park St      4    h  1600000.0
# ...           ...           ...               ...    ...  ...        ...
# 18391       23540  Williamstown   8/2 Thompson St      2    t   622500.0
# 18392       23541  Williamstown      96 Verdon St      4    h  2500000.0
# 18393       23544     Yallambie      17 Amaroo Wy      4    h  1100000.0
# 18394       23545    Yarraville        6 Agnes St      4    h  1285000.0
# 18395       23546    Yarraville     33 Freeman St      4    h  1050000.0
#
# ...

# %%
df_clean = df.dropna()
df_cleans=df.dropna(axis=1)

# %%
df.isnull
# Out:
# <bound method DataFrame.isnull of        Unnamed: 0        Suburb           Address  Rooms Type      Price  \
# 0               1    Abbotsford      85 Turner St      2    h  1480000.0
# 1               2    Abbotsford   25 Bloomburg St      2    h  1035000.0
# 2               4    Abbotsford      5 Charles St      3    h  1465000.0
# 3               5    Abbotsford  40 Federation La      3    h   850000.0
# 4               6    Abbotsford       55a Park St      4    h  1600000.0
# ...           ...           ...               ...    ...  ...        ...
# 18391       23540  Williamstown   8/2 Thompson St      2    t   622500.0
# 18392       23541  Williamstown      96 Verdon St      4    h  2500000.0
# 18393       23544     Yallambie      17 Amaroo Wy      4    h  1100000.0
# 18394       23545    Yarraville        6 Agnes St      4    h  1285000.0
# 18395       23546    Yarraville     33 Freeman St      4    h  1050000.0
#
# ...

# %%
df['Landsize']= df['Landsize'].fillna(df['Landsize'].mean())
df['Car']=df['Car'].fillna(df['Car'].median())

# %%
df['Suburb'].unique()
# Out:
# <StringArray>
# [     'Abbotsford',    'Airport West',     'Albert Park',      'Alphington',
#           'Altona',    'Altona North',        'Armadale',      'Ascot Vale',
#        'Ashburton',         'Ashwood',
#  ...
#       'Whittlesea',        'Burnside',    'New Gisborne', 'Patterson Lakes',
#           'Wallan',        'Laverton',        'Lilydale',        'Plumpton',
#          'croydon',         'Monbulk']
# Length: 330, dtype: str

# %%
df['Suburb'].nunique
# Out:
# <bound method IndexOpsMixin.nunique of 0          Abbotsford
# 1          Abbotsford
# 2          Abbotsford
# 3          Abbotsford
# 4          Abbotsford
#              ...
# 18391    Williamstown
# 18392    Williamstown
# 18393       Yallambie
# 18394      Yarraville
# 18395      Yarraville
# Name: Suburb, Length: 18396, dtype: str>

# %%
df.corr(numeric_only=True)
# Out:
#                Unnamed: 0     Rooms     Price  Distance  Postcode  Bedroom2  \
# Unnamed: 0       1.000000  0.063194 -0.071270  0.267362  0.104123  0.103046
# Rooms            0.063194  1.000000  0.496430  0.286979  0.063034  0.948740
# Price           -0.071270  0.496430  1.000000 -0.169779  0.098790  0.474864
# Distance         0.267362  0.286979 -0.169779  1.000000  0.443318  0.294835
# Postcode         0.104123  0.063034  0.098790  0.443318  1.000000  0.064956
# Bedroom2         0.103046  0.948740  0.474864  0.294835  0.064956  1.000000
# Bathroom         0.042097  0.597444  0.463762  0.130633  0.114387  0.589968
# Car              0.068693  0.364080  0.204104  0.235028  0.049440  0.408214
# Landsize         0.022088  0.021997  0.032111  0.020961  0.020152  0.024483
# BuildingArea     0.014801  0.127357  0.094342  0.093891  0.051753  0.125580
# YearBuilt        0.135943 -0.060499 -0.324032  0.250276  0.044442 -0.048461
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt 

sns.heatmap(df.isnull())
plt.show()

# %%
plt.scatter(x='Rooms',y='Price', data = df)
plt.show()

# %%
numeric_features = ['Rooms','Distance','Price','Bedroom2','Bathroom','Landsize','BuildingArea','Postcode','Longtitude','Lattitude']
df_numeric = df[numeric_features]

# %%
plt.figure(figsize=(8,6))
plt.scatter(df['Rooms'],df['Price'])
plt.title("Rooms vs Price")
plt.xlabel = ("Rooms")
plt.ylabel('Price')
plt.show()

# %%
#multiple features scatter plot 
sns.pairplot(df_numeric,x_vars=['Rooms','Bathroom','Bedroom2','Distance','Postcode'],y_vars='Price', kind='scatter')
plt.show()

# %%
# !pip install scikit-learn
import sklearn
print(sklearn.__version__)
# Out:
# ...
# 1.8.0

# %%
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
x = df[['Rooms','Distance','Postcode']]
y = df['Price']

# %%
x = x.fillna(x.median())

# %%
print(df.isnull().sum())
# Out:
# Unnamed: 0           0
# Suburb               0
# Address              0
# Rooms                0
# Type                 0
# Price                0
# Method               0
# SellerG              0
# Date                 0
# Distance             1
# Postcode             1
# Bedroom2          3469
# Bathroom          3471
# Car                  0
# Landsize             0
# BuildingArea     10634
# YearBuilt         9438
# CouncilArea       6163
# Lattitude         3332
# Longtitude        3332
# Regionname           1
# Propertycount        1
# dtype: int64

# %%
df["Bedroom2"] = df["Bedroom2"]. fillna(df["Bedroom2"].median())
df["Bathroom"]= df["Bathroom"].fillna(df["Bathroom"].median())
df["Distance"]= df["Distance"].fillna(df["Distance"].mean())
df["Postcode"]= df["Postcode"].fillna(df["Postcode"].median())
df["Lattitude"]= df["Lattitude"].fillna(df['Lattitude'].mean())
df["Longtitude"]= df["Longtitude"].fillna(df["Longtitude"].mean())

# %%
df["CouncilArea"]= df["CouncilArea"].fillna(df["CouncilArea"].mode()[0])
df["Regionname"]= df["Regionname"].fillna(df["Regionname"].mode()[0])

# %%
df = df.drop(['BuildingArea','YearBuilt'], axis = 1)

# %%
df = pd.get_dummies(df, drop_first=True)

# %%
print(df.isnull().sum())
# Out:
# Unnamed: 0                               0
# Rooms                                    0
# Price                                    0
# Distance                                 0
# Postcode                                 0
#                                         ..
# Regionname_Northern Victoria             0
# Regionname_South-Eastern Metropolitan    0
# Regionname_Southern Metropolitan         0
# Regionname_Western Metropolitan          0
# Regionname_Western Victoria              0
# Length: 18880, dtype: int64

# %%
x_train.dropna()
y_train.dropna()
# Out:
# 750      1800000.0
# 4058     1650000.0
# 1190      930000.0
# 5245     1637000.0
# 14005     766000.0
#            ...
# 11284     670000.0
# 11964    1494000.0
# 5390     1082000.0
# 860      1310000.0
# 15795     540000.0
# Name: Price, Length: 14716, dtype: float64

# %%
print(x_train.isnull().sum())
print(y_train.isnull().sum())
# Out:
# Rooms       0
# Distance    0
# Postcode    0
# dtype: int64
# 0

# %%
x_train.isnull()
# Out:
#        Rooms  Distance  Postcode
# 750    False     False     False
# 4058   False     False     False
# 1190   False     False     False
# 5245   False     False     False
# 14005  False     False     False
# ...      ...       ...       ...
# 11284  False     False     False
# 11964  False     False     False
# 5390   False     False     False
# 860    False     False     False
# 15795  False     False     False
#
# [14716 rows x 3 columns]

# %%
x = x.dropna()
y = y.dropna()

# %%
print(x.columns)
# Out:
# Index(['Rooms', 'Distance', 'Postcode'], dtype='str')

# %%
x_train, x_test , y_train, y_test = train_test_split (x,y, random_state=42, test_size = 0.2)
x_train.shape
# Out:
# (14716, 3)

# %%
lr_model = LinearRegression()
lr_model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr_model.predict(x_test)

# %%
lr_mse = mean_squared_error(y_pred, y_test)
print("LR Mean Squared Error:",lr_mse)
# Out:
# LR Mean Squared Error: 231060445935.42215

# %%
lr_r2score = r2_score(y_pred, y_test)
print("LR r2 score:",lr_r2score)
# Out:
# LR r2 score: -0.4363162582996163

# %%
#Predict predicited values and actual values 
plt.scatter(y_test, y_pred )
plt.plot([y_test.min(), y_test.max()],
         [y_test.min(), y_test.max()],
         color='red')
plt.title('Actual Price')
plt.ylabel('predicated price')
plt.show()

# %%
#Conclusion: The model captures the general trend of house prices but shows significant deviations from the ideal prediction line.
#The model performs well with mid or low priced houses but unable to predict better for high priced houses ,
#  the model performs even well with feature engineering , using advanced models can improve the performance.

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
features = ['Postcode','Bathroom','Bedroom2','Car','Landsize','Rooms','Distance']
x = df[features]   # ✅ must be a DataFrame
y = df['Price']

# %%
x_train, x_test , y_train, y_test = train_test_split(x,y, test_size=0.2, random_state=42)

# %%
RR_model = RandomForestRegressor()
RR_model.fit(x_train,y_train)
# Out:
# RandomForestRegressor()

# %%
y_pred = RR_model.predict(x_test)

# %%
RR_mse = mean_squared_error(y_pred,y_test)
print("RR Mean Squared Error:", RR_mse)
# Out:
# RR Mean Squared Error: 148196673002.67355

# %%
RR_r2_score = r2_score(y_test, y_pred) 
print("RR r2 score:",RR_r2_score)
# Out:
# RR r2 score: 0.6298293635169167

# %%
importances = RR_model.feature_importances_
feat_importances = pd.DataFrame({
    'Feature': x.columns, 
    'Importance': importances
    }).sort_values(by='Importance', ascending=False)
print(feat_importances)
# Out:
#     Feature  Importance
# 1  Distance    0.356943
# 0     Rooms    0.342590
# 2  Postcode    0.300467

# %%
plt.Figure(figsize=(8,6))
sns.barplot(x='Importance',y='Feature', data= feat_importances, palette='viridis')
plt.title('Feature Importance for House Price Prediction')
plt.show()
# Out:
# C:\Users\Swati Goud\AppData\Local\Temp\ipykernel_26208\4003214388.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Importance',y='Feature', data= feat_importances, palette='viridis')

# %% [markdown]
# Distance Feature contributes the most to prediction

# %% [markdown]
# Comparision: Linear & RR Model
# Random Regressor model performs well than linear model , RR model has r2 score 0.46 and in linear model .
# Mean_squared Error for RR model is less

# %%
n_estmators_list =[10,90,150,350,45]
mse_list = []
r2_list= []

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import root_mean_squared_error, r2_score
from sklearn.metrics import r2_score

# %%
#Decision Tree 
x1= df[['Distance','Postcode','Bedroom2','Bathroom']]
y1 = df['Price']

# %%
x1_train, x1_test, y1_train, y1_test= train_test_split(x1, y1, test_size=0.2,  random_state=42)

# %%
decision_tree = DecisionTreeRegressor(random_state=42)

decision_tree.fit(x1_train, y1_train)
# Out:
# DecisionTreeRegressor(random_state=42)

# %%
y1_pred = decision_tree.predict(x1_test)

# %%
dt_mse = mean_squared_error(y1_pred, y1_test) 
print("Decision Tree Mean Squared Error:",dt_mse)
# Out:
# Decision Tree Mean Squared Error: 202556629446.47116

# %%
dt_mae =mean_absolute_error(y1_pred, y1_test)
print("Decision Tree Mean Absolute Error:",dt_mae)
# Out:
# Decision Tree Mean Absolute Error: 277197.86215777503

# %%
dt_rmse = root_mean_squared_error(y1_test, y1_pred) 
print("DT RMSE :", dt_rmse)
# Out:
# DT RMSE : 450062.9172087733

# %%
dt_r2_score = r2_score(y1_test, y1_pred)
print("DT r2_score:",dt_r2_score)
# Out:
# DT r2_score: 0.4940472351581361

# %%
xx= df[['Distance','Postcode','Bedroom2','Bathroom']]
yy = df['Price']

# %%
xx_train, xx_test, yy_train, yy_test = train_test_split(xx, yy, test_size=0.2, random_state=42)

# %%
from sklearn.ensemble import RandomForestRegressor
